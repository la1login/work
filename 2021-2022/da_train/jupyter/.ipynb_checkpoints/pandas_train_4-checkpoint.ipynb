# %%
import pandas as pd

# %%
df = pd.read_csv('customers.csv')

# %%
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

# %%
df['Age'].hist(bins=15);

# %%
df.groupby('Gender')['Annual Income (k$)'].mean()
# Out:
# Gender
# Female    59.250000
# Male      62.227273
# Name: Annual Income (k$), dtype: float64

# %%
df['Age'].plot(kind='bar', title='Amount of different age people');

# %%
df.plot(x='Age', y='Annual Income (k$)', kind='scatter');

# %%
df[df['Gender'] == "Female"]['Annual Income (k$)'].hist(alpha=0.7)
df[df['Gender'] == "Male"]['Annual Income (k$)'].hist(alpha=0.7)
plt.legend(['F', 'M']);

# %%
a = df.groupby(['Age', 'Gender'])['Annual Income (k$)'].sum()

# %%
a
# Out:
# Age  Gender
# 18   Female     65
#      Male      140
# 19   Female    128
#      Male      328
# 20   Female     53
#               ...
# 67   Male      135
# 68   Female    107
#      Male       63
# 69   Male       44
# 70   Male       95
# Name: Annual Income (k$), Length: 87, dtype: int64

# %%
a.plot();

# %% [markdown]
# # Missing values

# %%
df.isna()
# Out:
#      CustomerID  Gender    Age  Annual Income (k$)  Spending Score (1-100)
# 0         False   False  False               False                   False
# 1         False   False  False               False                   False
# 2         False   False  False               False                   False
# 3         False   False  False               False                   False
# 4         False   False  False               False                   False
# ..          ...     ...    ...                 ...                     ...
# 195       False   False  False               False                   False
# 196       False   False  False               False                   False
# 197       False   False  False               False                   False
# 198       False   False  False               False                   False
# 199       False   False  False               False                   False
#
# [200 rows x 5 columns]

# %%
df.isna().any()
# Out:
# CustomerID                False
# Gender                    False
# Age                       False
# Annual Income (k$)        False
# Spending Score (1-100)    False
# dtype: bool

# %%
df.isna().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
#remove missing values
df.dropna();

# %%
# NaN -> 0
df.fillna(0);

# %% [markdown]
# # Creating DataFrames

# %%
list_of_dict = [
    {'name': 'Ginger', 'breed': 'Dachshund', 'height_cm': 22,
    'weight_kg': 10, 'date_of_birth': '2019-03-14'},
    {'name': 'Scout', 'breed': 'Dalmatain', 'height_cm': 59,
    'weight_kg': 25, 'date_of_birth': '2019-05-09'}
]

# %%
dogs_list = pd.DataFrame(list_of_dict)

# %%
dogs_list
# Out:
#      name      breed  height_cm  weight_kg date_of_birth
# 0  Ginger  Dachshund         22         10    2019-03-14
# 1   Scout  Dalmatain         59         25    2019-05-09

# %%
dict_of_list = {
    'name': ['Ginger', 'Scout'],
    'breed': ['Dachshund', 'Dalmatain'],
    'height': [22, 59],
    'weight': [10, 25],
    'date_of_birth': ['2019-03-04', '2019-05-09']
}

# %%
dogs_dict = pd.DataFrame(dict_of_list)

# %%
dogs_dict
# Out:
#      name      breed  height  weight date_of_birth
# 0  Ginger  Dachshund      22      10    2019-03-04
# 1   Scout  Dalmatain      59      25    2019-05-09

# %% [markdown]
# # Reading and writing CSVs

# %% [markdown]
# ### Creating CSV with Python

# %%
columns = ['name', 'breed', 'height', 'weight', 'd_o_b']
data = [
    ['Ginger','Labrador',22,10,'2019-03-04'],
    ['Scout','Alabay',59,25,'2019-05-09']
]

# %%
import os
os.path.abspath('jupyter/customers.csv')
# Out:
# '/Users/sergejloginov/work/2021-2022/da_train/jupyter/jupyter/customers.csv'

# %%
import csv
with open('dogs.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerow(columns)
    writer.writerows(data)

# %%
new_dogs = pd.read_csv('dogs.csv')

# %%
new_dogs
# Out:
#      name     breed  height  weight       d_o_b
# 0  Ginger  Labrador      22      10  2019-03-04
# 1   Scout    Alabay      59      25  2019-05-09

# %%
 new_dogs['bmi'] = new_dogs['weight'] / (new_dogs['height'] / 100) ** 2

# %%
new_dogs
# Out:
#      name     breed  height  weight       d_o_b         bmi
# 0  Ginger  Labrador      22      10  2019-03-04  206.611570
# 1   Scout    Alabay      59      25  2019-05-09   71.818443

# %%
new_dogs.to_csv('new_dogs.csv')

# %% [markdown]
# # Inner join
# ### Возвращаются строки данных с совпадающими значениями в ключевых столбцах обеих таблиц

# %%
import numpy as np
c = ['CustomerID', 'Study level', 'Age']
d = []
for i in range(200):
    d.append([i+1, np.random.randint(0,6), np.random.randint(18,70)])

# %%
cust_df = pd.DataFrame(d, columns=c)

# %%
cust_df
# Out:
#      CustomerID  Study level  Age
# 0             1            2   22
# 1             2            2   29
# 2             3            4   18
# 3             4            4   41
# 4             5            3   51
# ..          ...          ...  ...
# 195         196            2   50
# 196         197            3   57
# 197         198            1   30
# 198         199            3   31
# 199         200            5   46
#
# [200 rows x 3 columns]

# %%
cust_join = df.merge(cust_df, on='CustomerID')

# %%
cust_join
# Out:
#      CustomerID  Gender  Age_x  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male     19                  15                      39
# 1             2    Male     21                  15                      81
# 2             3  Female     20                  16                       6
# 3             4  Female     23                  16                      77
# 4             5  Female     31                  17                      40
# ..          ...     ...    ...                 ...                     ...
# 195         196  Female     35                 120                      79
# 196         197  Female     45                 126                      28
# 197         198    Male     32                 126                      74
# 198         199    Male     32                 137                      18
# 199         200    Male     30                 137                      83
#
#      Study level  Age_y
# 0              2     22
# 1              2     29
# 2              4     18
# 3              4     41
# 4              3     51
# ..           ...    ...
# 195            2     50
# 196            3     57
# 197            1     30
# 198            3     31
# 199            5     46
#
# [200 rows x 7 columns]

# %%
cust_join = df.merge(cust_df, on='CustomerID', suffixes=('_fst', '_scd'))

# %%
cust_join
# Out:
#      CustomerID  Gender  Age_fst  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male       19                  15                      39
# 1             2    Male       21                  15                      81
# 2             3  Female       20                  16                       6
# 3             4  Female       23                  16                      77
# 4             5  Female       31                  17                      40
# ..          ...     ...      ...                 ...                     ...
# 195         196  Female       35                 120                      79
# 196         197  Female       45                 126                      28
# 197         198    Male       32                 126                      74
# 198         199    Male       32                 137                      18
# 199         200    Male       30                 137                      83
#
#      Study level  Age_scd
# 0              2       22
# 1              2       29
# 2              4       18
# 3              4       41
# 4              3       51
# ..           ...      ...
# 195            2       50
# 196            3       57
# 197            1       30
# 198            3       31
# 199            5       46
#
# [200 rows x 7 columns]

# %%
cust_join.groupby('Study level').agg({'CustomerID': 'count'})
# Out:
#              CustomerID
# Study level
# 0                    33
# 1                    29
# 2                    36
# 3                    34
# 4                    34
# 5                    34

# %% [markdown]
# ## 3 or more tables:
# df1.merge(df2, on='col') \\
#
#     .merge(df3, on='col)

# %% [markdown]
# # Left join
# ### Возвращаются все строки левой таблицы и только те строки правой, где совпадают ключевые столбцы

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202022-02-07%20%D0%B2%2011.33.52.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202022-02-07%20%D0%B2%2011.33.52.png)

# %%
c1 = ['CustomerID', 'Study level', 'Age']
d1 = []
for i in range(10):
    d1.append([i+1, np.random.randint(0,6), np.random.randint(18,70)])
cust_df1 = pd.DataFrame(d1, columns=c1)

# %%
cust_df1
# Out:
#    CustomerID  Study level  Age
# 0           1            4   25
# 1           2            4   60
# 2           3            2   22
# 3           4            4   29
# 4           5            0   36
# 5           6            4   29
# 6           7            0   25
# 7           8            5   39
# 8           9            4   24
# 9          10            0   60

# %%
cust_df1_left_join = cust_df1.merge(df, on='CustomerID', how='left')

# %%
cust_df1_left_join
# Out:
#    CustomerID  Study level  Age_x  Gender  Age_y  Annual Income (k$)  \
# 0           1            4     25    Male     19                  15
# 1           2            4     60    Male     21                  15
# 2           3            2     22  Female     20                  16
# 3           4            4     29  Female     23                  16
# 4           5            0     36  Female     31                  17
# 5           6            4     29  Female     22                  17
# 6           7            0     25  Female     35                  18
# 7           8            5     39  Female     23                  18
# 8           9            4     24    Male     64                  19
# 9          10            0     60  Female     30                  19
#
#    Spending Score (1-100)
# 0                      39
# 1                      81
# 2                       6
# 3                      77
# 4                      40
# 5                      76
# 6                       6
# 7                      94
# 8                       3
# 9                      72

# %%
df1_left_join = df.merge(cust_df1, on='CustomerID', how='left')

# %%
df1_left_join
# Out:
#      CustomerID  Gender  Age_x  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male     19                  15                      39
# 1             2    Male     21                  15                      81
# 2             3  Female     20                  16                       6
# 3             4  Female     23                  16                      77
# 4             5  Female     31                  17                      40
# ..          ...     ...    ...                 ...                     ...
# 195         196  Female     35                 120                      79
# 196         197  Female     45                 126                      28
# 197         198    Male     32                 126                      74
# 198         199    Male     32                 137                      18
# 199         200    Male     30                 137                      83
#
#      Study level  Age_y
# 0            4.0   25.0
# 1            4.0   60.0
# 2            2.0   22.0
# 3            4.0   29.0
# 4            0.0   36.0
# ..           ...    ...
# 195          NaN    NaN
# 196          NaN    NaN
# 197          NaN    NaN
# 198          NaN    NaN
# 199          NaN    NaN
#
# [200 rows x 7 columns]

# %% [markdown]
# # Right join
# ### Зеркальный аналог Left join

# %%
c2 = ['CustomerID_new', 'Study level', 'Age']
d2 = []
for i in range(10):
    d2.append([i+1, np.random.randint(0,6), np.random.randint(18,70)])

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202022-02-07%20%D0%B2%2012.40.16.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202022-02-07%20%D0%B2%2012.40.16.png)

# %%
cust_df2 = pd.DataFrame(d2, columns=c2)

# %%
cust_df2
# Out:
#    CustomerID_new  Study level  Age
# 0               1            4   26
# 1               2            1   51
# 2               3            5   52
# 3               4            0   69
# 4               5            5   43
# 5               6            2   38
# 6               7            1   44
# 7               8            1   69
# 8               9            1   59
# 9              10            0   42

# %%
cust_df_right_join = df.merge(cust_df2, how='right', left_on='CustomerID',\
                             right_on='CustomerID_new')

# %%
cust_df_right_join
# Out:
#    CustomerID  Gender  Age_x  Annual Income (k$)  Spending Score (1-100)  \
# 0           1    Male     19                  15                      39
# 1           2    Male     21                  15                      81
# 2           3  Female     20                  16                       6
# 3           4  Female     23                  16                      77
# 4           5  Female     31                  17                      40
# 5           6  Female     22                  17                      76
# 6           7  Female     35                  18                       6
# 7           8  Female     23                  18                      94
# 8           9    Male     64                  19                       3
# 9          10  Female     30                  19                      72
#
#    CustomerID_new  Study level  Age_y
# 0               1            4     26
# 1               2            1     51
# 2               3            5     52
# 3               4            0     69
# 4               5            5     43
# 5               6            2     38
# 6               7            1     44
# 7               8            1     69
# 8               9            1     59
# 9              10            0     42

# %%
cust_custdf2_right_join = cust_df2.merge(df, how='right',\
                                       left_on='CustomerID_new',\
                                       right_on='CustomerID')

# %%
cust_custdf2_right_join
# Out:
#      CustomerID_new  Study level  Age_x  CustomerID  Gender  Age_y  \
# 0               1.0          4.0   26.0           1    Male     19
# 1               2.0          1.0   51.0           2    Male     21
# 2               3.0          5.0   52.0           3  Female     20
# 3               4.0          0.0   69.0           4  Female     23
# 4               5.0          5.0   43.0           5  Female     31
# ..              ...          ...    ...         ...     ...    ...
# 195             NaN          NaN    NaN         196  Female     35
# 196             NaN          NaN    NaN         197  Female     45
# 197             NaN          NaN    NaN         198    Male     32
# 198             NaN          NaN    NaN         199    Male     32
# 199             NaN          NaN    NaN         200    Male     30
#
#      Annual Income (k$)  Spending Score (1-100)
# 0                    15                      39
# 1                    15                      81
# 2                    16                       6
# 3                    16                      77
# 4                    17                      40
# ..                  ...                     ...
# 195                 120                      79
# 196                 126                      28
# 197                 126                      74
# 198                 137                      18
# 199                 137                      83
#
# [200 rows x 8 columns]

# %% [markdown]
# # Outer join
# ### Возвращаются все строки обеих таблиц независимо от совпадения между таблицами

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202022-02-07%20%D0%B2%2012.41.40.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202022-02-07%20%D0%B2%2012.41.40.png)

# %%
c3, c4 = ['movie_id', 'genre'], ['movie_id', 'genre']
d3, d4 = [], []
for i in range(3):
    d3.append([np.random.randint(0,100), 'Family'])
    d4.append([np.random.randint(0,100), 'Comedy'])
movies1, movies2 = pd.DataFrame(d3, columns=c3), pd.DataFrame(d4, columns=c4)

# %%
movies1
# Out:
#    movie_id   genre
# 0        31  Family
# 1        78  Family
# 2        17  Family

# %%
movies2
# Out:
#    movie_id   genre
# 0        46  Comedy
# 1        84  Comedy
# 2        88  Comedy

# %%
fam_com = movies1.merge(movies2, on='movie_id', how='outer',\
                       suffixes=['_fam', '_com'])
fam_com
# Out:
#    movie_id genre_fam genre_com
# 0        31    Family       NaN
# 1        78    Family       NaN
# 2        17    Family       NaN
# 3        46       NaN    Comedy
# 4        84       NaN    Comedy
# 5        88       NaN    Comedy

# %%
family_only = fam_com[fam_com['genre_com'].isnull()]

# %%
family_only
# Out:
#    movie_id genre_fam genre_com
# 0        31    Family       NaN
# 1        78    Family       NaN
# 2        17    Family       NaN

# %% [markdown]
# # Self join

# %%
head = ['id', 'title', 'sequel']
data = [
    [19995, 'Avatar', None],
    [862, 'Toy Story', 863],
    [863, 'Toy Story 2', 10193],
    [597, 'Titanic', None],
    [10193, 'Toy Story 3', None]
]
df = pd.DataFrame(data, columns=head)

# %%
df
# Out:
#       id        title   sequel
# 0  19995       Avatar      NaN
# 1    862    Toy Story    863.0
# 2    863  Toy Story 2  10193.0
# 3    597      Titanic      NaN
# 4  10193  Toy Story 3      NaN

# %%
df_sequels = df.merge(df, left_on='sequel', right_on='id',
                     suffixes=['_org', '_seq'])

# %%
df_sequels
# Out:
#    id_org    title_org  sequel_org  id_seq    title_seq  sequel_seq
# 0     862    Toy Story       863.0     863  Toy Story 2     10193.0
# 1     863  Toy Story 2     10193.0   10193  Toy Story 3         NaN

# %%
df_sequels = df.merge(df, left_on='sequel', right_on='id',
                     suffixes=['_org', '_seq'], how='left')

# %%
df_sequels
# Out:
#    id_org    title_org  sequel_org   id_seq    title_seq  sequel_seq
# 0   19995       Avatar         NaN      NaN          NaN         NaN
# 1     862    Toy Story       863.0    863.0  Toy Story 2     10193.0
# 2     863  Toy Story 2     10193.0  10193.0  Toy Story 3         NaN
# 3     597      Titanic         NaN      NaN          NaN         NaN
# 4   10193  Toy Story 3         NaN      NaN          NaN         NaN

# %%
df = pd.read_csv('customers.csv')
bool_filter = ((df['Age'] >= 30) 
               & (df['Annual Income (k$)'] 
                  == df['Annual Income (k$)'].max()))

# %%
df[bool_filter]
# Out:
#      CustomerID Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 198         199   Male   32                 137                      18
# 199         200   Male   30                 137                      83

# %% [markdown]
# # Merging on indexes

# %%
cust_df = cust_df.set_index('CustomerID')

# %%
df = pd.read_csv('customers.csv', index_col=['CustomerID'])
df
# Out:
#             Gender  Age  Annual Income (k$)  Spending Score (1-100)
# CustomerID
# 1             Male   19                  15                      39
# 2             Male   21                  15                      81
# 3           Female   20                  16                       6
# 4           Female   23                  16                      77
# 5           Female   31                  17                      40
# ...            ...  ...                 ...                     ...
# 196         Female   35                 120                      79
# 197         Female   45                 126                      28
# 198           Male   32                 126                      74
# 199           Male   32                 137                      18
# 200           Male   30                 137                      83
#
# [200 rows x 4 columns]

# %%
df_cust_merged_indexes = df.merge(cust_df, on='CustomerID',
                                 how='left')
# for join with more than 1 index use 
#list of indexes like on=['x', 'y']

# %%
df_cust_merged_indexes
# Out:
#             Gender  Age_x  Annual Income (k$)  Spending Score (1-100)  \
# CustomerID
# 1             Male     19                  15                      39
# 2             Male     21                  15                      81
# 3           Female     20                  16                       6
# 4           Female     23                  16                      77
# 5           Female     31                  17                      40
# ...            ...    ...                 ...                     ...
# 196         Female     35                 120                      79
# 197         Female     45                 126                      28
# 198           Male     32                 126                      74
# 199           Male     32                 137                      18
# 200           Male     30                 137                      83
#
#             Study level  Age_y
# CustomerID
# 1                     2     22
# 2                     2     29
# 3                     4     18
# 4                     4     41
# 5                     3     51
# ...                 ...    ...
# 196                   2     50
# 197                   3     57
# 198                   1     30
# 199                   3     31
# 200                   5     46
#
# [200 rows x 6 columns]

# %%
cust_df = cust_df.reset_index()

# %%
cust_df['id'] = cust_df['CustomerID']

# %%
cust_df
# Out:
#      CustomerID  Study level  Age   id
# 0             1            2   22    1
# 1             2            2   29    2
# 2             3            4   18    3
# 3             4            4   41    4
# 4             5            3   51    5
# ..          ...          ...  ...  ...
# 195         196            2   50  196
# 196         197            3   57  197
# 197         198            1   30  198
# 198         199            3   31  199
# 199         200            5   46  200
#
# [200 rows x 4 columns]

# %%
cust_df = cust_df.set_index('id')

# %%
df_merge_different_indexes = df.merge(cust_df, 
            left_on='CustomerID',
            right_on='id')

# %%
df_merge_different_indexes
# Out:
#             Gender  Age_x  Annual Income (k$)  Spending Score (1-100)  \
# CustomerID
# 1             Male     19                  15                      39
# 2             Male     21                  15                      81
# 3           Female     20                  16                       6
# 4           Female     23                  16                      77
# 5           Female     31                  17                      40
# ...            ...    ...                 ...                     ...
# 196         Female     35                 120                      79
# 197         Female     45                 126                      28
# 198           Male     32                 126                      74
# 199           Male     32                 137                      18
# 200           Male     30                 137                      83
#
#             Study level  Age_y
# CustomerID
# 1                     2     22
# 2                     2     29
# 3                     4     18
# 4                     4     41
# 5                     3     51
# ...                 ...    ...
# 196                   2     50
# 197                   3     57
# 198                   1     30
# 199                   3     31
# 200                   5     46
#
# [200 rows x 6 columns]

# %% [markdown]
# # Filtering joins

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202022-02-07%20%D0%B2%2022.01.19.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202022-02-07%20%D0%B2%2022.01.19.png)

# %%
c1 = ['CustomerID', 'Study level', 'Age']
d1 = []
for i in range(10):
    d1.append([i+1, np.random.randint(0,6), np.random.randint(18,70)])
cust_df1 = pd.DataFrame(d1, columns=c1)

# %%
df = pd.read_csv('customers.csv')

# %%
df_merged = df.merge(cust_df1, on='CustomerID')

# %%
df_merged
# Out:
#    CustomerID  Gender  Age_x  Annual Income (k$)  Spending Score (1-100)  \
# 0           1    Male     19                  15                      39
# 1           2    Male     21                  15                      81
# 2           3  Female     20                  16                       6
# 3           4  Female     23                  16                      77
# 4           5  Female     31                  17                      40
# 5           6  Female     22                  17                      76
# 6           7  Female     35                  18                       6
# 7           8  Female     23                  18                      94
# 8           9    Male     64                  19                       3
# 9          10  Female     30                  19                      72
#
#    Study level  Age_y
# 0            1     25
# 1            0     46
# 2            4     33
# 3            4     59
# 4            3     42
# 5            1     61
# 6            3     42
# 7            1     36
# 8            0     48
# 9            3     62

# %%
df["CustomerID"].isin(cust_df1['CustomerID'])
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# Name: CustomerID, Length: 200, dtype: bool

# %%
df_filter_semi = df[df["CustomerID"].isin(cust_df1['CustomerID'])]

# %%
df_filter_semi
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
# 5           6  Female   22                  17                      76
# 6           7  Female   35                  18                       6
# 7           8  Female   23                  18                      94
# 8           9    Male   64                  19                       3
# 9          10  Female   30                  19                      72

# %% [markdown]
# # Anti join

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202022-02-07%20%D0%B2%2022.09.47.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202022-02-07%20%D0%B2%2022.09.47.png)

# %%
df_filter_anti = df.merge(cust_df1, on='CustomerID', how='left', 
                          indicator=True)

# %%
df_filter_anti
# Out:
#      CustomerID  Gender  Age_x  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male     19                  15                      39
# 1             2    Male     21                  15                      81
# 2             3  Female     20                  16                       6
# 3             4  Female     23                  16                      77
# 4             5  Female     31                  17                      40
# ..          ...     ...    ...                 ...                     ...
# 195         196  Female     35                 120                      79
# 196         197  Female     45                 126                      28
# 197         198    Male     32                 126                      74
# 198         199    Male     32                 137                      18
# 199         200    Male     30                 137                      83
#
#      Study level  Age_y     _merge
# 0            1.0   25.0       both
# 1            0.0   46.0       both
# 2            4.0   33.0       both
# 3            4.0   59.0       both
# 4            3.0   42.0       both
# ..           ...    ...        ...
# 195          NaN    NaN  left_only
# 196          NaN    NaN  left_only
# 197          NaN    NaN  left_only
# 198          NaN    NaN  left_only
# 199          NaN    NaN  left_only
#
# [200 rows x 8 columns]

# %%
anti_filter = df_filter_anti.loc[df_filter_anti['_merge'] == 'left_only', 'CustomerID']

# %%
anti_filter
# Out:
# 10      11
# 11      12
# 12      13
# 13      14
# 14      15
#       ...
# 195    196
# 196    197
# 197    198
# 198    199
# 199    200
# Name: CustomerID, Length: 190, dtype: int64

# %%
df_filter_anti = df[df['CustomerID'].isin(anti_filter)]

# %%
df_filter_anti
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 10           11    Male   67                  19                      14
# 11           12  Female   35                  19                      99
# 12           13  Female   58                  20                      15
# 13           14  Female   24                  20                      77
# 14           15    Male   37                  20                      13
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [190 rows x 5 columns]

# %%
df_merge_different_indexes.groupby('Study level').agg({'Annual Income (k$)': 'count'})
# Out:
#              Annual Income (k$)
# Study level
# 0                            33
# 1                            29
# 2                            36
# 3                            34
# 4                            34
# 5                            34

# %% [markdown]
# # Concatenate DataFrames together vertically

# %%
head = ['a', 'b', 'c']
data = []
data1 = []
for i in range(3):
    data.append(['a' + str(i+1), 'b' + str(i+1), 'c' + str(i+1)])
    data1.append(['a' + str(i+4), 'b' + str(i+4), 'c' + str(i+4)])
df_concatenate, df_concatenate1 = pd.DataFrame(data, columns=head),\
pd.DataFrame(data1, columns=head)

# %%
df_concatenate
# Out:
#     a   b   c
# 0  a1  b1  c1
# 1  a2  b2  c2
# 2  a3  b3  c3

# %%
df_concatenate1
# Out:
#     a   b   c
# 0  a4  b4  c4
# 1  a5  b5  c5
# 2  a6  b6  c6

# %%
pd.concat([df_concatenate, df_concatenate1], ignore_index=True,
         keys=['first', 'second'])
# Out:
#     a   b   c
# 0  a1  b1  c1
# 1  a2  b2  c2
# 2  a3  b3  c3
# 3  a4  b4  c4
# 4  a5  b5  c5
# 5  a6  b6  c6

# %%
vert_conc = pd.concat([df_concatenate, df_concatenate1],
                      ignore_index=False, keys=['first', 'second'])

# %%
vert_conc
# Out:
#            a   b   c
# first  0  a1  b1  c1
#        1  a2  b2  c2
#        2  a3  b3  c3
# second 0  a4  b4  c4
#        1  a5  b5  c5
#        2  a6  b6  c6

# %%
df_concatenate1['d'] = 'd'

# %%
pd.concat([df_concatenate, df_concatenate1], sort=True)
# Out:
#     a   b   c    d
# 0  a1  b1  c1  NaN
# 1  a2  b2  c2  NaN
# 2  a3  b3  c3  NaN
# 0  a4  b4  c4    d
# 1  a5  b5  c5    d
# 2  a6  b6  c6    d

# %%
pd.concat([df_concatenate, df_concatenate1], join='inner') 
#default join='outer'
# Out:
#     a   b   c
# 0  a1  b1  c1
# 1  a2  b2  c2
# 2  a3  b3  c3
# 0  a4  b4  c4
# 1  a5  b5  c5
# 2  a6  b6  c6

# %%
df_concatenate.append(df_concatenate1, ignore_index=True, sort=True)
# Out:
#     a   b   c    d
# 0  a1  b1  c1  NaN
# 1  a2  b2  c2  NaN
# 2  a3  b3  c3  NaN
# 3  a4  b4  c4    d
# 4  a5  b5  c5    d
# 5  a6  b6  c6    d

# %% [markdown]
# # Verifying integrity

# %%
head = ['tid', 'name', 'aid', 'u_price']
data = [
    [2, 'Name1', 3, 1.99],
    [3, 'Name2', 2, 1.99],
    [4, 'Name3', 3, 1.99]
]
df1 = pd.DataFrame(data, columns=head)

# %%
head = ['tid', 'ms', 'bytes']
data = [
    [2, 342562, 5510424],
    [3, 230619, 3990994],
    [2, 252051, 4331779]
]
df2 = pd.DataFrame(data, columns=head)

# %%
df1
# Out:
#    tid   name  aid  u_price
# 0    2  Name1    3     1.99
# 1    3  Name2    2     1.99
# 2    4  Name3    3     1.99

# %%
df2
# Out:
#    tid      ms    bytes
# 0    2  342562  5510424
# 1    3  230619  3990994
# 2    2  252051  4331779

# %%
df1.merge(df2, on='tid', validate='one_to_one') 
# will error cause of relation one to many(2 value 2 in 2 table)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-586-0ef7b38e5d77> in <module>
# ----> 1 df1.merge(df2, on='tid', validate='one_to_one')
#       2 # will error cause of relation one to many(2 value 2 in 2 table)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    8193         from pandas.core.reshape.merge import merge
#    8194
# -> 8195         return merge(
#    8196             self,
#    8197             right,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     676         # are in fact unique.
#     677         if validate is not None:
# --> 678             self._validate(validate)
#     679
#     680     def get_result(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py in _validate(self, validate)
#    1364                 )
#    1365             elif not right_unique:
# -> 1366                 raise MergeError(
#    1367                     "Merge keys are not unique in right dataset; not a one-to-one merge"
#    1368                 )
#
# MergeError: Merge keys are not unique in right dataset; not a one-to-one merge

# %%
df1.merge(df2, on='tid', validate='one_to_many')
# Out:
#    tid   name  aid  u_price      ms    bytes
# 0    2  Name1    3     1.99  342562  5510424
# 1    2  Name1    3     1.99  252051  4331779
# 2    3  Name2    2     1.99  230619  3990994

# %% [markdown]
# .concat() check indexes, so df ,ust be indexed

# %%
df1 = df1.set_index('tid')

# %%
df2 = df2.set_index('tid')

# %%
df1
# Out:
#       name  aid  u_price
# tid
# 2    Name1    3     1.99
# 3    Name2    2     1.99
# 4    Name3    3     1.99

# %%
df2
# Out:
#          ms    bytes
# tid
# 2    342562  5510424
# 3    230619  3990994
# 2    252051  4331779

# %%
pd.concat([df1, df2], verify_integrity=True)
# will error cause have equal indexes in both table 2 and 3
# in first and 2 and 3 in second
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-594-82cf2990de2a> in <module>
# ----> 1 pd.concat([df1, df2], verify_integrity=True)
#       2 # will error cause have equal indexes in both table 2 and 3
#       3 # in first and 2 and 3 in second
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     283     ValueError: Indexes have overlapping values: ['a']
#     284     """
# --> 285     op = _Concatenator(
#     286         objs,
#     287         axis=axis,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     465         self.copy = copy
#     466
# --> 467         self.new_axes = self._get_new_axes()
#     468
#     469     def get_result(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in _get_new_axes(self)
#     535     def _get_new_axes(self) -> List[Index]:
#     536         ndim = self._get_result_dim()
# --> 537         return [
#     538             self._get_concat_axis() if i == self.bm_axis else self._get_comb_axis(i)
#     539             for i in range(ndim)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in <listcomp>(.0)
#     536         ndim = self._get_result_dim()
#     537         return [
# --> 538             self._get_concat_axis() if i == self.bm_axis else self._get_comb_axis(i)
#     539             for i in range(ndim)
#     540         ]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in _get_concat_axis(self)
#     596             )
#     597
# --> 598         self._maybe_check_integrity(concat_axis)
#     599
#     600         return concat_axis
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in _maybe_check_integrity(self, concat_index)
#     604             if not concat_index.is_unique:
#     605                 overlap = concat_index[concat_index.duplicated()].unique()
# --> 606                 raise ValueError(f"Indexes have overlapping values: {overlap}")
#     607
#     608
#
# ValueError: Indexes have overlapping values: Int64Index([2, 3], dtype='int64', name='tid')

# %%
pd.concat([df1, df2], verify_integrity=False)
# Out:
#       name  aid  u_price        ms      bytes
# tid
# 2    Name1  3.0     1.99       NaN        NaN
# 3    Name2  2.0     1.99       NaN        NaN
# 4    Name3  3.0     1.99       NaN        NaN
# 2      NaN  NaN      NaN  342562.0  5510424.0
# 3      NaN  NaN      NaN  230619.0  3990994.0
# 2      NaN  NaN      NaN  252051.0  4331779.0

# %% [markdown]
# # Merging ordered and Time-series Data

# %% [markdown]
# ### Using merge_ordered( )

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202022-02-08%20%D0%B2%2020.45.33.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202022-02-08%20%D0%B2%2020.45.33.png)

# %%
head = ['date', 'close']
data1 = [
    ['2007-02-01', 12.087143],
    ['2007-03-01', 13.272857],
    ['2007-04-01', 14.257143],
    ['2007-05-01', 17.312857],
    ['2007-06-01', 17.434286],
]
data2 = [
    ['2007-01-01', 44.349998],
    ['2007-02-01', 43.689999],
    ['2007-03-01', 45.049999],
    ['2007-04-01', 48.279999],
    ['2007-05-01', 50.549999],
]
df1, df2 = pd.DataFrame(data1, columns=head),pd.DataFrame(data2, columns=head)

# %%
df1
# Out:
#          date      close
# 0  2007-02-01  12.087143
# 1  2007-03-01  13.272857
# 2  2007-04-01  14.257143
# 3  2007-05-01  17.312857
# 4  2007-06-01  17.434286

# %%
df2
# Out:
#          date      close
# 0  2007-01-01  44.349998
# 1  2007-02-01  43.689999
# 2  2007-03-01  45.049999
# 3  2007-04-01  48.279999
# 4  2007-05-01  50.549999

# %%
pd.merge_ordered(df1, df2, on='date', suffixes=['_df1', '_df2'])
# Out:
#          date  close_df1  close_df2
# 0  2007-01-01        NaN  44.349998
# 1  2007-02-01  12.087143  43.689999
# 2  2007-03-01  13.272857  45.049999
# 3  2007-04-01  14.257143  48.279999
# 4  2007-05-01  17.312857  50.549999
# 5  2007-06-01  17.434286        NaN

# %%
pd.merge_ordered(df1, df2, on='date', suffixes=['_df1', '_df2'],
                fill_method='ffill')
# Out:
#          date  close_df1  close_df2
# 0  2007-01-01        NaN  44.349998
# 1  2007-02-01  12.087143  43.689999
# 2  2007-03-01  13.272857  45.049999
# 3  2007-04-01  14.257143  48.279999
# 4  2007-05-01  17.312857  50.549999
# 5  2007-06-01  17.434286  50.549999

# %% [markdown]
# ### Using merge_asof( )

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202022-02-08%20%D0%B2%2021.12.25-2.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202022-02-08%20%D0%B2%2021.12.25-2.png)

# %%
head = ['date_time', 'close']
data1 = [
    ['2017-11-17 16:00:00', 110.32],
    ['2017-11-17 17:00:00', 110.24],
    ['2017-11-17 18:00:00', 110.065],
    ['2017-11-17 19:00:00', 110.04],
    ['2017-11-17 20:00:00', 110.0],
    ['2017-11-17 21:00:00', 109.9966],
    ['2017-11-17 22:00:00', 109.82]
]
data2 = [
    ['2017-11-17 15:35:12', 149.3],
    ['2017-11-17 15:40:34', 149.13],
    ['2017-11-17 15:45:50', 148.98],
    ['2017-11-17 15:50:20', 148.99],
    ['2017-11-17 15:55:10', 149.11],
    ['2017-11-17 16:00:03', 149.25],
    ['2017-11-17 16:05:06', 149.5175],
    ['2017-11-17 16:10:12', 149.57],
    ['2017-11-17 16:15:30', 149.59],
    ['2017-11-17 16:20:32', 149.82],
]
df1, df2 = pd.DataFrame(data1, columns=head),pd.DataFrame(data2, columns=head)

# %%
df1
# Out:
#              date_time     close
# 0  2017-11-17 16:00:00  110.3200
# 1  2017-11-17 17:00:00  110.2400
# 2  2017-11-17 18:00:00  110.0650
# 3  2017-11-17 19:00:00  110.0400
# 4  2017-11-17 20:00:00  110.0000
# 5  2017-11-17 21:00:00  109.9966
# 6  2017-11-17 22:00:00  109.8200

# %%
df2
# Out:
#              date_time     close
# 0  2017-11-17 15:35:12  149.3000
# 1  2017-11-17 15:40:34  149.1300
# 2  2017-11-17 15:45:50  148.9800
# 3  2017-11-17 15:50:20  148.9900
# 4  2017-11-17 15:55:10  149.1100
# 5  2017-11-17 16:00:03  149.2500
# 6  2017-11-17 16:05:06  149.5175
# 7  2017-11-17 16:10:12  149.5700
# 8  2017-11-17 16:15:30  149.5900
# 9  2017-11-17 16:20:32  149.8200

# %% [markdown]
# Errors so read anythere

# %% [markdown]
# ### Selecting data with .query( )

# %%
df2
# Out:
#              date_time     close
# 0  2017-11-17 15:35:12  149.3000
# 1  2017-11-17 15:40:34  149.1300
# 2  2017-11-17 15:45:50  148.9800
# 3  2017-11-17 15:50:20  148.9900
# 4  2017-11-17 15:55:10  149.1100
# 5  2017-11-17 16:00:03  149.2500
# 6  2017-11-17 16:05:06  149.5175
# 7  2017-11-17 16:10:12  149.5700
# 8  2017-11-17 16:15:30  149.5900
# 9  2017-11-17 16:20:32  149.8200

# %%
df2.query('close >= 149')
# Out:
#              date_time     close
# 0  2017-11-17 15:35:12  149.3000
# 1  2017-11-17 15:40:34  149.1300
# 4  2017-11-17 15:55:10  149.1100
# 5  2017-11-17 16:00:03  149.2500
# 6  2017-11-17 16:05:06  149.5175
# 7  2017-11-17 16:10:12  149.5700
# 8  2017-11-17 16:15:30  149.5900
# 9  2017-11-17 16:20:32  149.8200

# %%
df2.query('close >=149 and close <= 149.13')
# Out:
#              date_time   close
# 1  2017-11-17 15:40:34  149.13
# 4  2017-11-17 15:55:10  149.11

# %%
df2.query('close == 149.11 or close == "lol"')
# Out:
#              date_time   close
# 4  2017-11-17 15:55:10  149.11

# %% [markdown]
# ### Reshaping data with.melt( )
