# %%
import Pkg

# %%
Pkg.add("JuMP")
# Out:
#     Updating registry at `~/.julia/registries/General`
#    Resolving package versions...
#    Installed HarfBuzz_jll ─────── v2.8.1+1
#    Installed Glib_jll ─────────── v2.68.3+2
#    Installed Cairo_jll ────────── v1.16.1+1
#    Installed CodecZlib ────────── v0.7.0
#    Installed JSONSchema ───────── v0.3.4
#    Installed Calculus ─────────── v0.5.1
#    Installed CodecBzip2 ───────── v0.7.2
#    Installed TranscodingStreams ─ v0.9.6
#    Installed MathOptInterface ─── v0.9.22
#    Installed JuMP ─────────────── v0.21.10
#     Updating `~/.julia/environments/v1.6/Project.toml`
#   [4076af6c] + JuMP v0.21.10
#     Updating `~/.julia/environments/v1.6/Manifest.toml`
#   [49dc2e85] + Calculus v0.5.1
#   [523fee87] + CodecBzip2 v0.7.2
#   [944b1d66] + CodecZlib v0.7.0
#   [7d188eb4] + JSONSchema v0.3.4
#   [4076af6c] + JuMP v0.21.10
#   [b8f27783] + MathOptInterface v0.9.22
#   [3bb67fe8] + TranscodingStreams v0.9.6
#   [83423d85] ↑ Cairo_jll v1.16.1+0 ⇒ v1.16.1+1
#   [7746bdde] ↑ Glib_jll v2.68.3+0 ⇒ v2.68.3+2
#   [2e76f6c2] ↑ HarfBuzz_jll v2.8.1+0 ⇒ v2.8.1+1
# Precompiling project...
#   ✓ JSONSchema
#   ✓ Calculus
#   ✓ TranscodingStreams
#   ✓ CodecZlib
#   ✓ CodecBzip2
#   ✓ Glib_jll
#   ✓ Cairo_jll
#   ✓ Qt5Base_jll
#   ✓ HarfBuzz_jll
#   ✓ libass_jll
#   ✓ FFMPEG_jll
#   ✓ FFMPEG
#   ✓ GR_jll
#   ✓ GR
#   ✓ MathOptInterface
#   ✓ Plots
#   ✓ JuMP
#   17 dependencies successfully precompiled in 48 seconds (274 already precompiled)

# %%
Pkg.add("GLPK")
# Out:
#    Resolving package versions...
#    Installed GLPK_jll ─────── v5.0.0+0
#    Installed BinaryProvider ─ v0.5.10
#    Installed GLPK ─────────── v0.14.14
#     Updating `~/.julia/environments/v1.6/Project.toml`
#   [60bf3e95] + GLPK v0.14.14
#     Updating `~/.julia/environments/v1.6/Manifest.toml`
#   [b99e7846] + BinaryProvider v0.5.10
#   [60bf3e95] + GLPK v0.14.14
#   [e8aa6df9] + GLPK_jll v5.0.0+0
#   [781609d7] + GMP_jll
#     Building GLPK → `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/833dbc8fbb0554e31186df509d67fc2f78f1bb09/build.log`
# Precompiling project...
#   ✓ GMP_jll
#   ✓ GLPK_jll
#   ✓ BinaryProvider
#   ✓ GLPK
#   4 dependencies successfully precompiled in 6 seconds (291 already precompiled)

# %%
using JuMP
using GLPK

# %%
model = Model(GLPK.Optimizer)
# Out:
# A JuMP Model
# Feasibility problem with:
# Variables: 0
# Model mode: AUTOMATIC
# CachingOptimizer state: EMPTY_OPTIMIZER
# Solver name: GLPK

# %%
@variable(model, x >= 0)
@variable(model, y >= 0)
# Out:
# y

# %%
@constraint(model, 6x + 8y >= 100)
@constraint(model, 7x +12y >= 120)
# Out:
# 7 x + 12 y ≥ 120.0

# %%
@objective(model, Min, 12x + 20y)
# Out:
# 12 x + 20 y

# %%
optimize!(model)

# %%
termination_status(model)
# Out:
# OPTIMAL::TerminationStatusCode = 1

# %%
@show value(x);
@show value(y);
# Out:
# value(x) = 14.999999999999993
# value(y) = 1.2500000000000047

# %%
@show objective_value(model)
# Out:
# objective_value(model) = 205.0
# 205.0

# %%
vector_model = Model(GLPK.Optimizer)
# Out:
# A JuMP Model
# Feasibility problem with:
# Variables: 0
# Model mode: AUTOMATIC
# CachingOptimizer state: EMPTY_OPTIMIZER
# Solver name: GLPK

# %%
A = [1 1 9 5; 3 5 0 8; 2 0 6 13]
b = [7; 3; 5]
c = [1; 3; 5; 2];

# %%
@variable(vector_model, x[1:4] >= 0)
# Out:
# 4-element Vector{VariableRef}:
#  x[1]
#  x[2]
#  x[3]
#  x[4]

# %%
@constraint(vector_model, A*x .== b)
# Out:
# 3-element Vector{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.EqualTo{Float64}}, ScalarShape}}:
#  x[1] + x[2] + 9 x[3] + 5 x[4] = 7.0
#  3 x[1] + 5 x[2] + 8 x[4] = 3.0
#  2 x[1] + 6 x[3] + 13 x[4] = 5.0

# %%
@objective(vector_model, Min, c' * x)
# Out:
# x[1] + 3 x[2] + 5 x[3] + 2 x[4]

# %%
optimize!(vector_model)

# %%
termination_status(vector_model)
# Out:
# OPTIMAL::TerminationStatusCode = 1

# %%
@show objective_value(vector_model)
# Out:
# objective_value(vector_model) = 4.9230769230769225
# 4.9230769230769225

# %%
category_data = JuMP.Containers.DenseAxisArray(
    [1800 2200;
    91 Inf;
    0 65;
    0 1779],
    ["calories", "protein", "fat", "sodium"],
    ["min", "max"])
# Out:
# 2-dimensional DenseAxisArray{Float64,2,...} with index sets:
#     Dimension 1, ["calories", "protein", "fat", "sodium"]
#     Dimension 2, ["min", "max"]
# And data, a 4×2 Matrix{Float64}:
#  1800.0  2200.0
#    91.0    Inf
#     0.0    65.0
#     0.0  1779.0

# %%
foods = ["hamburger", "chicken", "hot dog", "fries", "macaroni", 
    "pizza","salad", "milk", "ice cream"]
# Out:
# 9-element Vector{String}:
#  "hamburger"
#  "chicken"
#  "hot dog"
#  "fries"
#  "macaroni"
#  "pizza"
#  "salad"
#  "milk"
#  "ice cream"

# %%
cost = JuMP.Containers.DenseAxisArray(
  [2.49, 2.89, 1.50, 1.89, 2.09, 1.99, 2.49, 0.89, 1.59],
foods)
# Out:
# 1-dimensional DenseAxisArray{Float64,1,...} with index sets:
#     Dimension 1, ["hamburger", "chicken", "hot dog", "fries", "macaroni", "pizza", "salad", "milk", "ice cream"]
# And data, a 9-element Vector{Float64}:
#  2.49
#  2.89
#  1.5
#  1.89
#  2.09
#  1.99
#  2.49
#  0.89
#  1.59

# %%
food_data = JuMP.Containers.DenseAxisArray(
  [410 24 26 730;
   420 32 10 1190;
   560 20 32 1800;
   380  4 19 270;
   320 12 10 930;
   320 15 12 820;
   320 31 12 1230;
   100  8 2.5 125;
   330  8 10 180],
foods,
["calories", "protein", "fat", "sodium"])
# Out:
# 2-dimensional DenseAxisArray{Float64,2,...} with index sets:
#     Dimension 1, ["hamburger", "chicken", "hot dog", "fries", "macaroni", "pizza", "salad", "milk", "ice cream"]
#     Dimension 2, ["calories", "protein", "fat", "sodium"]
# And data, a 9×4 Matrix{Float64}:
#  410.0  24.0  26.0   730.0
#  420.0  32.0  10.0  1190.0
#  560.0  20.0  32.0  1800.0
#  380.0   4.0  19.0   270.0
#  320.0  12.0  10.0   930.0
#  320.0  15.0  12.0   820.0
#  320.0  31.0  12.0  1230.0
#  100.0   8.0   2.5   125.0
#  330.0   8.0  10.0   180.0

# %%
model = Model(GLPK.Optimizer)
# Out:
# A JuMP Model
# Feasibility problem with:
# Variables: 0
# Model mode: AUTOMATIC
# CachingOptimizer state: EMPTY_OPTIMIZER
# Solver name: GLPK

# %%
categories = ["calories", "protein", "fat", "sodium"]
# Out:
# 4-element Vector{String}:
#  "calories"
#  "protein"
#  "fat"
#  "sodium"

# %%
@variables(model, begin
    category_data[c, "min"] <= nutrition[c = categories] <=
        category_data[c, "max"]
  # Сколько покупать продуктов:
    buy[foods] >= 0 
end)

# %%
@objective(model, Min, sum(cost[f] * buy[f] for f in foods))
# Out:
# 2.49 buy[hamburger] + 2.89 buy[chicken] + 1.5 buy[hot dog] + 1.89 buy[fries] + 2.09 buy[macaroni] + 1.99 buy[pizza] + 2.49 buy[salad] + 0.89 buy[milk] + 1.59 buy[ice cream]

# %%
@constraint(model, [c in categories],
sum(food_data[f, c] * buy[f] for f in foods) == nutrition[c])
# Out:
# 1-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.EqualTo{Float64}}, ScalarShape},1,...} with index sets:
#     Dimension 1, ["calories", "protein", "fat", "sodium"]
# And data, a 4-element Vector{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.EqualTo{Float64}}, ScalarShape}}:
#  -nutrition[calories] + 410 buy[hamburger] + 420 buy[chicken] + 560 buy[hot dog] + 380 buy[fries] + 320 buy[macaroni] + 320 buy[pizza] + 320 buy[salad] + 100 buy[milk] + 330 buy[ice cream] = 0.0
#  -nutrition[protein] + 24 buy[hamburger] + 32 buy[chicken] + 20 buy[hot dog] + 4 buy[fries] + 12 buy[macaroni] + 15 buy[pizza] + 31 buy[salad] + 8 buy[milk] + 8 buy[ice cream] = 0.0
#  -nutrition[fat] + 26 buy[hamburger] + 10 buy[chicken] + 32 buy[hot dog] + 19 buy[fries] + 10 buy[macaroni] + 12 buy[pizza] + 12 buy[salad] + 2.5 buy[milk] + 10 buy[ice cream] = 0.0
#  -nutrition[sodium] + 730 buy[hamburger] + 1190 buy[chicken] + 1800 buy[hot dog] + 270 buy[fries] + 930 buy[macaroni] + 820 buy[pizza] + 1230 buy[salad] + 125 buy[milk] + 180 buy[ice cream] = 0.0

# %%
JuMP.optimize!(model)
term_status = JuMP.termination_status(model)
# Out:
# OPTIMAL::TerminationStatusCode = 1

# %%
hcat(buy.data,JuMP.value.(buy.data))
# Out:
# 9×2 Matrix{AffExpr}:
#  buy[hamburger]  0.6045138888888888
#  buy[chicken]    0
#  buy[hot dog]    0
#  buy[fries]      0
#  buy[macaroni]   0
#  buy[pizza]      0
#  buy[salad]      0
#  buy[milk]       6.9701388888888935
#  buy[ice cream]  2.591319444444441

# %%
;git clone https://github.com/ilyankou/passport-index-dataset.git
# Out:
# Cloning into 'passport-index-dataset'...

# %%
Pkg.add("DelimitedFiles")
# Out:
#    Resolving package versions...
#     Updating `~/.julia/environments/v1.6/Project.toml`
#   [8bb1440f] + DelimitedFiles
#   No Changes to `~/.julia/environments/v1.6/Manifest.toml`

# %%
Pkg.add("CSV")
# Out:
#    Resolving package versions...
#    Installed SentinelArrays ─ v1.3.10
#    Installed InlineStrings ── v1.1.1
#    Installed PooledArrays ─── v1.4.0
#    Installed FilePathsBase ── v0.9.17
#    Installed WeakRefStrings ─ v1.4.1
#    Installed CSV ──────────── v0.9.11
#     Updating `~/.julia/environments/v1.6/Project.toml`
#   [336ed68f] + CSV v0.9.11
#     Updating `~/.julia/environments/v1.6/Manifest.toml`
#   [336ed68f] + CSV v0.9.11
#   [48062228] + FilePathsBase v0.9.17
#   [842dd82b] + InlineStrings v1.1.1
#   [2dfb63ee] + PooledArrays v1.4.0
#   [91c51154] + SentinelArrays v1.3.10
#   [ea10d353] + WeakRefStrings v1.4.1
# Precompiling project...
#   ✓ PooledArrays
#   ✓ InlineStrings
#   ✓ SentinelArrays
#   ✓ FilePathsBase
#   ✓ WeakRefStrings
#   ✓ CSV
#   6 dependencies successfully precompiled in 9 seconds (295 already precompiled)

# %%
using DelimitedFiles
using CSV

# %%
passportdata = readdlm(joinpath("passport-index-dataset","passport-index-matrix.csv"),',')
# Out:
# 200×200 Matrix{Any}:
#  "Passport"                "Albania"    "Algeria"        …    "Afghanistan"
#  "Afghanistan"             "e-visa"     "visa required"     -1
#  "Albania"               -1             "visa required"       "visa required"
#  "Algeria"                 "e-visa"   -1                      "visa required"
#  "Andorra"               90             "visa required"       "visa required"
#  "Angola"                  "e-visa"     "visa required"  …    "visa required"
#  "Antigua and Barbuda"   90             "visa required"       "visa required"
#  "Argentina"             90             "visa required"       "visa required"
#  "Armenia"               90             "visa required"       "visa required"
#  "Australia"             90             "visa required"       "visa required"
#  "Austria"               90             "visa required"  …    "visa required"
#  "Azerbaijan"            90             "visa required"       "visa required"
#  "Bahamas"               90             "visa required"       "visa required"
#  ⋮                                                       ⋱
#  "United Arab Emirates"  90             "visa required"       "visa required"
#  "United Kingdom"        90             "visa required"       "visa required"
#  "United States"         90             "visa required"  …    "visa required"
#  "Uruguay"               90             "visa required"       "visa required"
#  "Uzbekistan"              "e-visa"     "visa required"       "visa required"
#  "Vanuatu"                 "e-visa"     "visa required"       "visa required"
#  "Vatican"               90             "visa required"       "visa required"
#  "Venezuela"             90             "visa required"  …    "visa required"
#  "Vietnam"                 "e-visa"     "visa required"       "visa required"
#  "Yemen"                   "e-visa"     "visa required"       "visa required"
#  "Zambia"                  "e-visa"     "visa required"       "visa required"
#  "Zimbabwe"                "e-visa"     "visa required"       "visa required"

# %%
cntr = passportdata[2:end,1]
vf=(x-> typeof(x)==Int64 || x=="VF" || x== "VOA" ? 1 :
0).(passportdata[2:end,2:end]);

# %%
model = Model(GLPK.Optimizer)
# Out:
# A JuMP Model
# Feasibility problem with:
# Variables: 0
# Model mode: AUTOMATIC
# CachingOptimizer state: EMPTY_OPTIMIZER
# Solver name: GLPK

# %%
@variable(model, pass[1:length(cntr)], Bin)
@constraint(model, [j=1:length(cntr)], sum( vf[i,j]*pass[i] for i in
            1:length(cntr)) >= 1)
@objective(model, Min, sum(pass))
# Out:
# pass[1] + pass[2] + pass[3] + pass[4] + pass[5] + pass[6] + pass[7] + pass[8] + pass[9] + pass[10] + pass[11] + pass[12] + pass[13] + pass[14] + pass[15] + pass[16] + pass[17] + pass[18] + pass[19] + pass[20] + pass[21] + pass[22] + pass[23] + pass[24] + pass[25] + pass[26] + pass[27] + pass[28] + pass[29] + pass[30] + pass[31] + pass[32] + pass[33] + pass[34] + pass[35] + pass[36] + pass[37] + pass[38] + pass[39] + pass[40] + pass[41] + pass[42] + pass[43] + pass[44] + pass[45] + pass[46] + pass[47] + pass[48] + pass[49] + pass[50] + pass[51] + pass[52] + pass[53] + pass[54] + pass[55] + pass[56] + pass[57] + pass[58] + pass[59] + pass[60] + pass[61] + pass[62] + pass[63] + pass[64] + pass[65] + pass[66] + pass[67] + pass[68] + pass[69] + pass[70] + pass[71] + pass[72] + pass[73] + pass[74] + pass[75] + pass[76] + pass[77] + pass[78] + pass[79] + pass[80] + pass[81] + pass[82] + pass[83] + pass[84] + pass[85] + pass[86] + pass[87] + pass[88] + pass[89] + pass[90] + pass[91] + pass[92] + pass[93] + pass[94] + pass[95] + pass[96] + pass[97] + pass[98] + pass[99] + pass[100] + pass[101] + pass[102] + pass[103] + pass[104] + pass[105] + pass[106] + pass[107] + pass[108] + pass[109] + pass[110] + pass[111] + pass[112] + pass[113] + pass[114] + pass[115] + pass[116] + pass[117] + pass[118] + pass[119] + pass[120] + pass[121] + pass[122] + pass[123] + pass[124] + pass[125] + pass[126] + pass[127] + pass[128] + pass[129] + pass[130] + pass[131] + pass[132] + pass[133] + pass[134] + pass[135] + pass[136] + pass[137] + pass[138] + pass[139] + pass[140] + pass[141] + pass[142] + pass[143] + pass[144] + pass[145] + pass[146] + pass[147] + pass[148] + pass[149] + pass[150] + pass[151] + pass[152] + pass[153] + pass[154] + pass[155] + pass[156] + pass[157] + pass[158] + pass[159] + pass[160] + pass[161] + pass[162] + pass[163] + pass[164] + pass[165] + pass[166] + pass[167] + pass[168] + pass[169] + pass[170] + pass[171] + pass[172] + pass[173] + pass[174] + pass[175] + pass[176] + pass[177] + pass[178] + pass[179] + pass[180] + pass[181] + pass[182] + pass[183] + pass[184] + pass[185] + pass[186] + pass[187] + pass[188] + pass[189] + pass[190] + pass[191] + pass[192] + pass[193] + pass[194] + pass[195] + pass[196] + pass[197] + pass[198] + pass[199]

# %%
JuMP.optimize!(model)
termination_status(model)
# Out:
# OPTIMAL::TerminationStatusCode = 1

# %%
print(JuMP.objective_value(model)," passports:",join(cntr[findall(JuMP.value.(pass) .== 1)],", "))
# Out:
# 55.0 passports:Afghanistan, Angola, Australia, Azerbaijan, Bahrain, Brunei, Cameroon, Comoros, DR Congo, Djibouti, Equatorial Guinea, Eritrea, Guinea-Bissau, Hungary, Indonesia, Iraq, Ireland, Israel, Jamaica, Japan, Kuwait, Laos, Liberia, Libya, Macao, Madagascar, Malaysia, Maldives, Marshall Islands, Mauritania, Micronesia, Morocco, Myanmar, Nauru, Nepal, New Zealand, North Korea, Palestine, Papua New Guinea, Philippines, Saudi Arabia, Singapore, Solomon Islands, Somalia, South Korea, South Sudan, Sri Lanka, Syria, Taiwan, Togo, Turkmenistan, United States, Vanuatu, Vietnam, Yemen

# %%
Pkg.add("DataFrames")
Pkg.add("XLSX")
Pkg.add("Plots")
Pkg.add("PyPlot")
Pkg.add("Convex")
Pkg.add("SCS")
Pkg.add("Statistics")
using DataFrames
using XLSX
using Plots
pyplot()
using Convex
using SCS
using Statistics
# Out:
#    Resolving package versions...
#    Installed InvertedIndices ─ v1.1.0
#    Installed DataFrames ────── v1.3.1
#    Installed PrettyTables ──── v1.3.1
#     Updating `~/.julia/environments/v1.6/Project.toml`
#   [a93c6f00] + DataFrames v1.3.1
#     Updating `~/.julia/environments/v1.6/Manifest.toml`
#   [a93c6f00] + DataFrames v1.3.1
#   [41ab1584] + InvertedIndices v1.1.0
#   [08abe8d2] + PrettyTables v1.3.1
# Precompiling project...
#   ✓ InvertedIndices
#   ✓ PrettyTables
#   ✓ DataFrames
#   3 dependencies successfully precompiled in 33 seconds (301 already precompiled)
#    Resolving package versions...
#    Installed ZipFile ─ v0.9.4
#    Installed EzXML ─── v1.1.0
#    Installed XLSX ──── v0.7.8
#     Updating `~/.julia/environments/v1.6/Project.toml`
#   [fdbf4ff8] + XLSX v0.7.8
#     Updating `~/.julia/environments/v1.6/Manifest.toml`
#   [8f5d6c58] + EzXML v1.1.0
#   [fdbf4ff8] + XLSX v0.7.8
#   [a5390f91] + ZipFile v0.9.4
# Precompiling project...
#   ✓ ZipFile
#   ✓ EzXML
#   ✓ XLSX
#   3 dependencies successfully precompiled in 4 seconds (304 already precompiled)
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.6/Project.toml`
#   No Changes to `~/.julia/environments/v1.6/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.6/Project.toml`
#   No Changes to `~/.julia/environments/v1.6/Manifest.toml`
#    Resolving package versions...
#    Installed AMD ─────────────── v0.4.0
#    Installed LDLFactorizations ─ v0.8.1
#    Installed Convex ──────────── v0.14.18
#     Updating `~/.julia/environments/v1.6/Project.toml`
#   [f65535da] + Convex v0.14.18
#     Updating `~/.julia/environments/v1.6/Manifest.toml`
#   [14f7f29c] + AMD v0.4.0
#   [f65535da] + Convex v0.14.18
#   [40e66cde] + LDLFactorizations v0.8.1
# Precompiling project...
#   ✓ AMD
#   ✓ LDLFactorizations
#   ✓ Convex
#   3 dependencies successfully precompiled in 9 seconds (307 already precompiled)
#    Resolving package versions...
#    Installed SCS_GPU_jll ── v2.1.4+0
#    Installed SCS ────────── v0.7.1
#    Installed MathProgBase ─ v0.7.8
#    Installed SCS_jll ────── v2.1.4+0
#     Updating `~/.julia/environments/v1.6/Project.toml`
#   [c946c3f1] + SCS v0.7.1
#     Updating `~/.julia/environments/v1.6/Manifest.toml`
#   [fdba3010] + MathProgBase v0.7.8
#   [c946c3f1] + SCS v0.7.1
#   [af6e375f] + SCS_GPU_jll v2.1.4+0
#   [f4f2fc5b] + SCS_jll v2.1.4+0
#     Building SCS → `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/efc1cf417dffb455b74a3d48857ae418098fc8a1/build.log`
# Precompiling project...
#   ✓ MathProgBase
#   ✓ SCS_GPU_jll
#   ✓ SCS_jll
#   ✓ SCS
#   4 dependencies successfully precompiled in 7 seconds (310 already precompiled)
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.6/Project.toml`
#   No Changes to `~/.julia/environments/v1.6/Manifest.toml`

# %%
T = DataFrame(XLSX.readtable("stock_prices.xlsx","Sheet2")...)
# Out:
# 13×3 DataFrame
#  Row │ MSFT    FB      AAPL
#      │ Any     Any     Any
# ─────┼────────────────────────
#    1 │ 101.93  137.95  148.26
#    2 │ 102.8   143.8   152.29
#    3 │ 107.71  150.04  156.82
#    4 │ 107.17  149.01  157.76
#    5 │ 102.78  165.71  166.52
#    6 │ 105.67  167.33  170.41
#    7 │ 108.22  162.5   170.42
#    8 │ 110.97  161.89  172.97
#    9 │ 112.53  162.28  174.97
#   10 │ 110.51  169.6   172.91
#   11 │ 115.91  165.98  186.12
#   12 │ 117.05  164.34  191.05
#   13 │ 117.94  166.69  189.95

# %%
plot(T[!,:MSFT],label="Microsoft")
  plot!(T[!,:AAPL],label="Apple")
  plot!(T[!,:FB],label="FB")

# %%
prices_matrix = Matrix(T)
# Out:
# 13×3 Matrix{Any}:
#  101.93  137.95  148.26
#  102.8   143.8   152.29
#  107.71  150.04  156.82
#  107.17  149.01  157.76
#  102.78  165.71  166.52
#  105.67  167.33  170.41
#  108.22  162.5   170.42
#  110.97  161.89  172.97
#  112.53  162.28  174.97
#  110.51  169.6   172.91
#  115.91  165.98  186.12
#  117.05  164.34  191.05
#  117.94  166.69  189.95

# %%
M1 = prices_matrix[1:end-1,:] 
M2 = prices_matrix[2:end,:]
# Out:
# 12×3 Matrix{Any}:
#  102.8   143.8   152.29
#  107.71  150.04  156.82
#  107.17  149.01  157.76
#  102.78  165.71  166.52
#  105.67  167.33  170.41
#  108.22  162.5   170.42
#  110.97  161.89  172.97
#  112.53  162.28  174.97
#  110.51  169.6   172.91
#  115.91  165.98  186.12
#  117.05  164.34  191.05
#  117.94  166.69  189.95

# %%
R = (M2.-M1)./M1
# Out:
# 12×3 Matrix{Float64}:
#   0.00853527   0.0424067    0.027182
#   0.0477626    0.0433936    0.0297459
#  -0.00501346  -0.00686484   0.00599413
#  -0.040963     0.112073     0.0555274
#   0.0281183    0.00977611   0.0233606
#   0.0241317   -0.0288651    5.8682e-5
#   0.0254112   -0.00375385   0.014963
#   0.0140579    0.00240904   0.0115627
#  -0.0179508    0.0451072   -0.0117734
#   0.0488644   -0.0213443    0.0763981
#   0.00983522  -0.00988071   0.0264883
#   0.00760359   0.0142996   -0.00575766

# %%
risk_matrix = cov(R)
# Out:
# 3×3 Matrix{Float64}:
#   0.000659383  -0.000630653  0.000139112
#  -0.000630653   0.00152162   0.000192288
#   0.000139112   0.000192288  0.000635503

# %%
isposdef(risk_matrix)
# Out:
# true

# %%
 r = mean(R,dims=1)[:]
# Out:
# 3-element Vector{Float64}:
#  0.012532748705136576
#  0.016563036855293173
#  0.021145804655032917

# %%
# Вектор инвестиций:
x = Variable(length(r))
# Out:
# Variable
# size: (3, 1)
# sign: real
# vexity: affine
# id: 146…926

# %%
problem = minimize(Convex.quadform(x,risk_matrix),[sum(x)==1;r'*x>=0.02;x.>=0])
# Out:
# minimize
# └─ * (convex; positive)
#    ├─ 1
#    └─ qol_elem (convex; positive)
#       ├─ norm2 (convex; positive)
#       │  └─ …
#       └─ [1.0]
# subject to
# ├─ == constraint (affine)
# │  ├─ sum (affine; real)
# │  │  └─ 3-element real variable (id: 146…926)
# │  └─ 1
# ├─ >= constraint (affine)
# │  ├─ * (affine; real)
# │  │  ├─ [0.0125327 0.016563 0.0211458]
# │  │  └─ 3-element real variable (id: 146…926)
# │  └─ 0.02
# ├─ >= constraint (affine)
# │  ├─ index (affine; real)
# │  │  └─ 3-element real variable (id: 146…926)
# │  └─ 0
# ├─ >= constraint (affine)
# │  ├─ index (affine; real)
# │  │  └─ 3-element real variable (id: 146…926)
# │  └─ 0
# └─ >= constraint (affine)
#    ├─ index (affine; real)
#    │  └─ 3-element real variable (id: 146…926)
#    └─ 0
#
# status: `solve!` not called yet

# %%
solve!(problem, SCS.Optimizer)
# Out:
# ----------------------------------------------------------------------------
# 	SCS v2.1.4 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-indirect, nnz in A = 24, CG tol ~ 1/iter^(2.00)
# eps = 1.00e-05, alpha = 1.50, max_iters = 5000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 6, constraints m = 14
# Cones:	primal zero / dual free vars: 2
# 	linear vars: 5
# 	soc vars: 7, soc blks: 2
# Setup time: 8.52e-05s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.71e+19  2.86e+19  1.00e+00 -3.40e+19  5.17e+18  5.49e+19  2.21e-05
#     99| 2.59e-11  7.73e-11  5.25e-11  4.85e-04  4.85e-04  1.49e-17  2.11e-03
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 2.11e-03s
# 	Lin-sys: avg # CG iterations: 3.28, avg solve time: 4.40e-07s
# 	Cones: avg projection time: 5.29e-08s
# 	Acceleration: avg step time: 2.00e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 1.4091e-16, dist(y, K*) = 0.0000e+00, s'y/|s||y| = 8.2412e-17
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 2.5893e-11
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 7.7263e-11
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 5.2529e-11
# ----------------------------------------------------------------------------
# c'x = 0.0005, -b'y = 0.0005
# ============================================================================

# %%
r'*x.value
# Out:
# 1×1 adjoint(::Vector{Float64}) with eltype Float64:
#  0.020000000000394896

# %%
Pkg.add("Images")
Pkg.add("Convex")
Pkg.add("SCS")
using Images
using Convex
using SCS
# Out:
#    Resolving package versions...
#    Installed IntelOpenMP_jll ─────────── v2018.0.3+2
#    Installed RangeArrays ─────────────── v0.3.2
#    Installed DualNumbers ─────────────── v0.6.6
#    Installed OpenEXR ─────────────────── v0.3.2
#    Installed ImageAxes ───────────────── v0.6.10
#    Installed IndirectArrays ──────────── v1.0.0
#    Installed Images ──────────────────── v0.25.0
#    Installed NearestNeighbors ────────── v0.4.9
#    Installed PkgVersion ──────────────── v0.1.1
#    Installed AxisAlgorithms ──────────── v1.0.1
#    Installed IntegralArrays ──────────── v0.1.2
#    Installed ImageSegmentation ───────── v1.7.0
#    Installed ProgressMeter ───────────── v1.7.1
#    Installed ComputationalResources ──── v0.3.2
#    Installed FFTViews ────────────────── v0.3.2
#    Installed TiffImages ──────────────── v0.5.2
#    Installed OpenEXR_jll ─────────────── v3.1.1+0
#    Installed CatIndices ──────────────── v0.2.2
#    Installed ImageMetadata ───────────── v0.9.8
#    Installed SimpleWeightedGraphs ────── v1.2.1
#    Installed Rotations ───────────────── v1.1.0
#    Installed AxisArrays ──────────────── v0.4.4
#    Installed CustomUnitRanges ────────── v1.0.2
#    Installed Netpbm ──────────────────── v1.0.2
#    Installed Ratios ──────────────────── v0.4.2
#    Installed ImageDistances ──────────── v0.2.15
#    Installed Imath_jll ───────────────── v3.1.2+0
#    Installed ImageIO ─────────────────── v0.5.9
#    Installed ImageTransformations ────── v0.9.3
#    Installed TiledIteration ──────────── v0.3.1
#    Installed ImageMorphology ─────────── v0.3.0
#    Installed RegionTrees ─────────────── v0.3.2
#    Installed ImageQualityIndexes ─────── v0.3.0
#    Installed FFTW ────────────────────── v1.4.5
#    Installed MetaGraphs ──────────────── v0.7.1
#    Installed JLD2 ────────────────────── v0.4.17
#    Installed PNGFiles ────────────────── v0.3.12
#    Installed Quaternions ─────────────── v0.4.2
#    Installed ImageShow ───────────────── v0.3.3
#    Installed WoodburyMatrices ────────── v0.5.5
#    Installed MKL_jll ─────────────────── v2021.1.1+2
#    Installed ImageBase ───────────────── v0.1.5
#    Installed FFTW_jll ────────────────── v3.3.10+0
#    Installed CoordinateTransformations ─ v0.6.2
#    Installed ImageFiltering ──────────── v0.7.1
#    Installed Clustering ──────────────── v0.14.2
#    Installed Interpolations ──────────── v0.13.5
#    Installed ImageContrastAdjustment ─── v0.3.10
#     Updating `~/.julia/environments/v1.6/Project.toml`
#   [916415d5] + Images v0.25.0
#     Updating `~/.julia/environments/v1.6/Manifest.toml`
#   [13072b0f] + AxisAlgorithms v1.0.1
#   [39de3d68] + AxisArrays v0.4.4
#   [aafaddc9] + CatIndices v0.2.2
#   [aaaa29a8] + Clustering v0.14.2
#   [ed09eef8] + ComputationalResources v0.3.2
#   [150eb455] + CoordinateTransformations v0.6.2
#   [dc8bdbbb] + CustomUnitRanges v1.0.2
#   [fa6b7ba4] + DualNumbers v0.6.6
#   [4f61f5a4] + FFTViews v0.3.2
#   [7a1cc6ca] + FFTW v1.4.5
#   [2803e5a7] + ImageAxes v0.6.10
#   [c817782e] + ImageBase v0.1.5
#   [f332f351] + ImageContrastAdjustment v0.3.10
#   [51556ac3] + ImageDistances v0.2.15
#   [6a3955dd] + ImageFiltering v0.7.1
#   [82e4d734] + ImageIO v0.5.9
#   [bc367c6b] + ImageMetadata v0.9.8
#   [787d08f9] + ImageMorphology v0.3.0
#   [2996bd0c] + ImageQualityIndexes v0.3.0
#   [80713f31] + ImageSegmentation v1.7.0
#   [4e3cecfd] + ImageShow v0.3.3
#   [02fcd773] + ImageTransformations v0.9.3
#   [916415d5] + Images v0.25.0
#   [9b13fd28] + IndirectArrays v1.0.0
#   [1d092043] + IntegralArrays v0.1.2
#   [a98d9a8b] + Interpolations v0.13.5
#   [033835bb] + JLD2 v0.4.17
#   [626554b9] + MetaGraphs v0.7.1
#   [b8a86587] + NearestNeighbors v0.4.9
#   [f09324ee] + Netpbm v1.0.2
#   [52e1d378] + OpenEXR v0.3.2
#   [f57f5aa1] + PNGFiles v0.3.12
#   [eebad327] + PkgVersion v0.1.1
#   [92933f4c] + ProgressMeter v1.7.1
#   [94ee1d12] + Quaternions v0.4.2
#   [b3c3ace0] + RangeArrays v0.3.2
#   [c84ed2f1] + Ratios v0.4.2
#   [dee08c22] + RegionTrees v0.3.2
#   [6038ab10] + Rotations v1.1.0
#   [47aef6b3] + SimpleWeightedGraphs v1.2.1
#   [731e570b] + TiffImages v0.5.2
#   [06e1c1a7] + TiledIteration v0.3.1
#   [efce3f68] + WoodburyMatrices v0.5.5
#   [f5851436] + FFTW_jll v3.3.10+0
#   [905a6f67] + Imath_jll v3.1.2+0
#   [1d5cc7b8] + IntelOpenMP_jll v2018.0.3+2
#   [856f044c] + MKL_jll v2021.1.1+2
#   [18a262bb] + OpenEXR_jll v3.1.1+0
#   [4af54fe1] + LazyArtifacts
# Precompiling project...
#   ✓ IndirectArrays
#   ✓ ProgressMeter
#   ✓ RangeArrays
#   ✓ Ratios
#   ✓ ComputationalResources
#   ✓ PkgVersion
#   ✓ WoodburyMatrices
#   ✓ CustomUnitRanges
#   ✓ FFTW_jll
#   ✓ TiledIteration
#   ✓ IntelOpenMP_jll
#   ✓ DualNumbers
#   ✓ Imath_jll
#   ✓ IntegralArrays
#   ✓ RegionTrees
#   ✓ NearestNeighbors
#   ✓ SimpleWeightedGraphs
#   ✓ CoordinateTransformations
#   ✓ AxisAlgorithms
#   ✓ AxisArrays
#   ✓ CatIndices
#   ✓ Quaternions
#   ✓ JLD2
#   ✓ MKL_jll
#   ✓ Netpbm
#   ✓ OpenEXR_jll
#   ✓ ImageBase
#   ✓ ImageMorphology
#   ✓ PNGFiles
#   ✓ OpenEXR
#   ✓ MetaGraphs
#   ✓ Clustering
#   ✓ Interpolations
#   ✓ ImageShow
#   ✓ Rotations
#   ✓ ImageDistances
#   ✓ ImageAxes
#   ✓ ImageMetadata
#   ✓ ImageTransformations
#   ✓ FFTW
#   ✓ FFTViews
#   ✓ ImageContrastAdjustment
#   ✓ TiffImages
#   ✓ ImageIO
#   ✓ ImageFiltering
#   ✓ ImageSegmentation
#   ✓ ImageQualityIndexes
#   ✓ Images
#   48 dependencies successfully precompiled in 69 seconds (326 already precompiled)
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.6/Project.toml`
#   No Changes to `~/.julia/environments/v1.6/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.6/Project.toml`
#   No Changes to `~/.julia/environments/v1.6/Manifest.toml`

# %%
Kref = load("khiam-small.jpg")
# Out:
# 283×283 Array{RGB{N0f8},2} with eltype RGB{N0f8}:
#  RGB{N0f8}(0.153,0.082,0.075)  …  RGB{N0f8}(0.678,0.659,0.675)
#  RGB{N0f8}(0.118,0.047,0.039)     RGB{N0f8}(0.514,0.494,0.51)
#  RGB{N0f8}(0.129,0.059,0.043)     RGB{N0f8}(0.624,0.604,0.62)
#  RGB{N0f8}(0.137,0.067,0.051)     RGB{N0f8}(0.157,0.137,0.153)
#  RGB{N0f8}(0.129,0.063,0.035)     RGB{N0f8}(0.243,0.224,0.239)
#  RGB{N0f8}(0.125,0.059,0.027)  …  RGB{N0f8}(0.184,0.161,0.176)
#  RGB{N0f8}(0.169,0.114,0.071)     RGB{N0f8}(0.208,0.184,0.2)
#  RGB{N0f8}(0.482,0.427,0.384)     RGB{N0f8}(0.153,0.129,0.145)
#  RGB{N0f8}(0.498,0.451,0.396)     RGB{N0f8}(0.141,0.106,0.125)
#  RGB{N0f8}(0.49,0.443,0.388)      RGB{N0f8}(0.161,0.125,0.145)
#  RGB{N0f8}(0.49,0.455,0.396)   …  RGB{N0f8}(0.149,0.114,0.125)
#  RGB{N0f8}(0.498,0.463,0.404)     RGB{N0f8}(0.145,0.102,0.118)
#  RGB{N0f8}(0.478,0.451,0.388)     RGB{N0f8}(0.145,0.102,0.118)
#  ⋮                             ⋱
#  RGB{N0f8}(0.51,0.49,0.478)       RGB{N0f8}(0.459,0.431,0.459)
#  RGB{N0f8}(0.49,0.475,0.439)      RGB{N0f8}(0.443,0.424,0.439)
#  RGB{N0f8}(0.51,0.494,0.459)      RGB{N0f8}(0.467,0.443,0.459)
#  RGB{N0f8}(0.482,0.471,0.443)     RGB{N0f8}(0.451,0.404,0.42)
#  RGB{N0f8}(0.463,0.459,0.439)  …  RGB{N0f8}(0.463,0.404,0.424)
#  RGB{N0f8}(0.443,0.443,0.435)     RGB{N0f8}(0.392,0.329,0.341)
#  RGB{N0f8}(0.471,0.475,0.482)     RGB{N0f8}(0.4,0.341,0.353)
#  RGB{N0f8}(0.471,0.482,0.502)     RGB{N0f8}(0.349,0.31,0.314)
#  RGB{N0f8}(0.537,0.557,0.58)      RGB{N0f8}(0.396,0.361,0.365)
#  RGB{N0f8}(0.529,0.557,0.588)  …  RGB{N0f8}(0.424,0.4,0.4)
#  RGB{N0f8}(0.541,0.569,0.6)       RGB{N0f8}(0.443,0.408,0.412)
#  RGB{N0f8}(0.541,0.576,0.604)     RGB{N0f8}(0.459,0.412,0.427)

# %%
K = copy(Kref)
p = prod(size(K))
missingids = rand(1:p,400)
K[missingids] .= RGBX{N0f8}(0.0,0.0,0.0) 
K
Gray.(K)
# Out:
# 283×283 Array{Gray{N0f8},2} with eltype Gray{N0f8}:
#  Gray{N0f8}(0.102)  Gray{N0f8}(0.063)  …  Gray{N0f8}(0.667)
#  Gray{N0f8}(0.067)  Gray{N0f8}(0.098)     Gray{N0f8}(0.502)
#  Gray{N0f8}(0.078)  Gray{N0f8}(0.086)     Gray{N0f8}(0.612)
#  Gray{N0f8}(0.086)  Gray{N0f8}(0.067)     Gray{N0f8}(0.145)
#  Gray{N0f8}(0.078)  Gray{N0f8}(0.102)     Gray{N0f8}(0.231)
#  Gray{N0f8}(0.075)  Gray{N0f8}(0.075)  …  Gray{N0f8}(0.169)
#  Gray{N0f8}(0.125)  Gray{N0f8}(0.098)     Gray{N0f8}(0.192)
#  Gray{N0f8}(0.439)  Gray{N0f8}(0.447)     Gray{N0f8}(0.137)
#  Gray{N0f8}(0.459)  Gray{N0f8}(0.455)     Gray{N0f8}(0.118)
#  Gray{N0f8}(0.451)  Gray{N0f8}(0.467)     Gray{N0f8}(0.137)
#  Gray{N0f8}(0.459)  Gray{N0f8}(0.459)  …  Gray{N0f8}(0.125)
#  Gray{N0f8}(0.467)  Gray{N0f8}(0.451)     Gray{N0f8}(0.118)
#  Gray{N0f8}(0.451)  Gray{N0f8}(0.451)     Gray{N0f8}(0.118)
#  ⋮                                     ⋱
#  Gray{N0f8}(0.494)  Gray{N0f8}(0.475)     Gray{N0f8}(0.443)
#  Gray{N0f8}(0.475)  Gray{N0f8}(0.482)     Gray{N0f8}(0.431)
#  Gray{N0f8}(0.494)  Gray{N0f8}(0.502)     Gray{N0f8}(0.451)
#  Gray{N0f8}(0.471)  Gray{N0f8}(0.494)     Gray{N0f8}(0.42)
#  Gray{N0f8}(0.459)  Gray{N0f8}(0.482)  …  Gray{N0f8}(0.424)
#  Gray{N0f8}(0.443)  Gray{N0f8}(0.459)     Gray{N0f8}(0.349)
#  Gray{N0f8}(0.475)  Gray{N0f8}(0.478)     Gray{N0f8}(0.361)
#  Gray{N0f8}(0.482)  Gray{N0f8}(0.478)     Gray{N0f8}(0.322)
#  Gray{N0f8}(0.553)  Gray{N0f8}(0.553)     Gray{N0f8}(0.373)
#  Gray{N0f8}(0.553)  Gray{N0f8}(0.545)  …  Gray{N0f8}(0.408)
#  Gray{N0f8}(0.565)  Gray{N0f8}(0.553)     Gray{N0f8}(0.42)
#  Gray{N0f8}(0.569)  Gray{N0f8}(0.553)     Gray{N0f8}(0.427)

# %%
Y = Float64.(Gray.(K));

# %%
correctids = findall(Y[:].!=0)
X = Convex.Variable(size(Y))
problem = minimize(nuclearnorm(X))
problem.constraints += X[correctids]==Y[correctids]
# Out:
# 1-element Vector{Constraint}:
#  == constraint (affine)
# ├─ index (affine; real)
# │  └─ 283×283 real variable (id: 140…767)
# └─ 79689-element Vector{Float64}

# %%
solve!(problem, SCS.Optimizer(eps=1e-3, alpha=1.5))
# Out:
# ----------------------------------------------------------------------------
# 	SCS v2.1.4 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-indirect, nnz in A = 400329, CG tol ~ 1/iter^(2.00)
# eps = 1.00e-03, alpha = 1.50, max_iters = 5000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 240268, constraints m = 400046
# Cones:	primal zero / dual free vars: 239585
# 	sd vars: 160461, sd blks: 1
# Setup time: 7.28e-02s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.04e+21  5.63e+19  1.00e+00 -1.54e+24  1.44e+22  1.16e+24  6.05e-01
#    100| 7.49e-02  3.69e-02  3.69e-04  4.41e+02  4.41e+02  7.78e-15  5.11e+01
#    200| 8.28e-03  7.55e-03  1.07e-04  4.45e+02  4.45e+02  8.99e-17  9.51e+01
#    300| 3.19e-01  1.94e-01  2.08e-05  4.46e+02  4.46e+02  1.22e-14  1.41e+02
#    400| 3.20e-03  1.81e-03  7.72e-07  4.46e+02  4.46e+02  1.28e-15  1.80e+02
#    500| 2.25e-03  1.20e-03  2.30e-06  4.46e+02  4.46e+02  1.83e-15  2.06e+02
#    600| 1.68e-02  1.02e-02  1.75e-08  4.46e+02  4.46e+02  6.17e-15  2.32e+02
#    700| 9.99e-04  6.05e-04  7.00e-07  4.46e+02  4.46e+02  2.02e-14  2.59e+02
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 2.59e+02s
# 	Lin-sys: avg # CG iterations: 6.37, avg solve time: 2.87e-02s
# 	Cones: avg projection time: 2.68e-01s
# 	Acceleration: avg step time: 6.06e-02s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 6.1553e-10, dist(y, K*) = 7.8266e-10, s'y/|s||y| = 3.9074e-13
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 9.9899e-04
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 6.0531e-04
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 6.9951e-07
# ----------------------------------------------------------------------------
# c'x = 445.6094, -b'y = 445.6088
# ============================================================================

# %%
@show norm(float.(Gray.(Kref))-X.value)
@show norm(-X.value)
colorview(Gray, X.value)
# Out:
# norm(float.(Gray.(Kref)) - X.value) = 1.1685825532353027
# norm(-(X.value)) = 124.34096427982992
# 283×283 reinterpret(reshape, Gray{Float64}, ::Matrix{Float64}) with eltype Gray{Float64}:
#  Gray{Float64}(0.10193)    …  Gray{Float64}(0.666726)
#  Gray{Float64}(0.0666613)     Gray{Float64}(0.501919)
#  Gray{Float64}(0.0784808)     Gray{Float64}(0.611712)
#  Gray{Float64}(0.0862538)     Gray{Float64}(0.145128)
#  Gray{Float64}(0.0782564)     Gray{Float64}(0.231348)
#  Gray{Float64}(0.0745367)  …  Gray{Float64}(0.168532)
#  Gray{Float64}(0.125421)      Gray{Float64}(0.192219)
#  Gray{Float64}(0.439211)      Gray{Float64}(0.137316)
#  Gray{Float64}(0.458857)      Gray{Float64}(0.117598)
#  Gray{Float64}(0.451005)      Gray{Float64}(0.137229)
#  Gray{Float64}(0.458761)   …  Gray{Float64}(0.125481)
#  Gray{Float64}(0.466669)      Gray{Float64}(0.117668)
#  Gray{Float64}(0.450951)      Gray{Float64}(0.117589)
#  ⋮                         ⋱
#  Gray{Float64}(0.494004)      Gray{Float64}(0.443275)
#  Gray{Float64}(0.474452)      Gray{Float64}(0.43136)
#  Gray{Float64}(0.494175)      Gray{Float64}(0.450889)
#  Gray{Float64}(0.470628)      Gray{Float64}(0.419545)
#  Gray{Float64}(0.458943)   …  Gray{Float64}(0.42353)
#  Gray{Float64}(0.443079)      Gray{Float64}(0.34902)
#  Gray{Float64}(0.474589)      Gray{Float64}(0.360943)
#  Gray{Float64}(0.482295)      Gray{Float64}(0.321569)
#  Gray{Float64}(0.552926)      Gray{Float64}(0.372712)
#  Gray{Float64}(0.552944)   …  Gray{Float64}(0.407998)
#  Gray{Float64}(0.564726)      Gray{Float64}(0.419575)
#  Gray{Float64}(0.568435)      Gray{Float64}(0.42736)
